# %% [markdown]
# #### Importamos las librerías necesarias para el análisis

# %%
import pandas as pd
import numpy as np
import random
import io

# %% [markdown]
# #### Leemos la base de datos a trabajar en nuestra ruta de origen

# %%
econdata = pd.read_csv('Econdata.csv')

# %% [markdown]
# #### Vemos los primeros registros de la tabla

# %%
econdata.head()
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
# 3   3      19.42489472,-99.12073393
# 4   4      19.42358238,-99.12451093
#
#                                            geo_shape   clave_cat  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12
# 3  {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 4  {"type": "MultiPoint", "coordinates": [[-99.12...  323_115_12
#
#             delegacion perimetro     tipo  \
# 0           Cuauhtémoc         B  Mercado
# 1            Cuautémoc         A    Museo
# 2            Cuautémoc         A    Museo
# 3  Venustiano Carranza         B    Hotel
# 4  Venustiano Carranza         B    Hotel
#
#                                               nom_id
# 0                                        Pino Suárez
# 1  Museo Nacional de Arquitectura Palacio de Bell...
# 2                                       Santa Teresa
# 3                                           Balbuena
# 4                                               real

# %% [markdown]
# # Funciones de muestreo:

# %% [markdown]
# ### 1) Muestreo aleatorio simple:

# %%
# Importamos 8 registros de manera aleatoria
aleat_8 = econdata.sample(n=8)
aleat_8
# Out:
#       id                  geo_point_2d  \
# 140  140  19.4374331486,-99.1457705763
# 49    49  19.4264953358,-99.1248854383
# 72    72  19.4454901265,-99.1471012862
# 93    93  19.4352977961,-99.1412872705
# 222  222   19.4397905042,-99.134628735
# 126  126      19.42774805,-99.12796532
# 150  150   19.440448428,-99.1365429261
# 23    23  19.4390916028,-99.1493421468
#
#                                              geo_shape   clave_cat  \
# 140  {"type": "MultiPoint", "coordinates": [[-99.14...  003_092_06
# 49   {"type": "Polygon", "coordinates": [[[-99.1252...  323_139_01
# 72   {"type": "MultiPoint", "coordinates": [[-99.14...  003_046_14
# 93   {"type": "MultiPoint", "coordinates": [[-99.14...  002_007_01
# 222  {"type": "MultiPoint", "coordinates": [[-99.13...  004_063_10
# 126  {"type": "MultiPoint", "coordinates": [[-99.12...  006_078_04
# 150  {"type": "MultiPoint", "coordinates": [[-99.13...  004_065_10
# 23   {"type": "MultiPoint", "coordinates": [[-99.14...  012_147_01
#
#               delegacion perimetro     tipo                   nom_id
# 140            Cuautémoc         A    Hotel          Boutique Cortes
# 49   Venustiano Carranza         B  Mercado      Dulceria Don Goloso
# 72             Cuautémoc         B    Hotel                   Atoyac
# 93             Cuautémoc         A    Museo  Palacio de Bellas Artes
# 222            Cuautémoc         A    Hotel                   Ladero
# 126            Cuautémoc         A    Hotel               San Marcos
# 150            Cuautémoc         B    Hotel                  Moderno
# 23             Cuautémoc         B    Hotel                La Fuente

# %%
# Repetimos el ejercicio y observamos que la selección aleatoria cambió
aleat_8_2 = econdata.sample(n=8)
aleat_8_2
# Out:
#       id                  geo_point_2d  \
# 177  177    19.43138889,-99.1370037108
# 208  208   19.423857491,-99.1225572301
# 226  226  19.4416748524,-99.1365878489
# 200  200  19.4340073515,-99.1372646267
# 12    12      19.43990186,-99.14813347
# 42    42  19.4368553413,-99.1196435872
# 3      3      19.42489472,-99.12073393
# 115  115  19.4336966991,-99.1237253904
#
#                                              geo_shape   clave_cat  \
# 177  {"type": "MultiPoint", "coordinates": [[-99.13...  001_030_06
# 208  {"type": "MultiPoint", "coordinates": [[-99.12...  323_108_11
# 226  {"type": "Polygon", "coordinates": [[[-99.1370...  004_052_01
# 200  {"type": "MultiPoint", "coordinates": [[-99.13...  001_014_02
# 12   {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
# 42   {"type": "MultiPoint", "coordinates": [[-99.11...  018_337_01
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 115  {"type": "MultiPoint", "coordinates": [[-99.12...  323_010_09
#
#               delegacion perimetro     tipo  \
# 177            Cuautémoc         A    Museo
# 208  Venustiano Carranza         B    Hotel
# 226           Cuauhtémoc         B  Mercado
# 200            Cuautémoc         A    Hotel
# 12             Cuautémoc         B    Hotel
# 42   Venustiano Carranza         B    Hotel
# 3    Venustiano Carranza         B    Hotel
# 115  Venustiano Carranza         B    Hotel
#
#                                    nom_id
# 177  Centro de Exposiciones Canter Europa
# 208                                Juárez
# 226                            De Muebles
# 200                          Buenos Aires
# 12                                 La Paz
# 42                         HOTEL RRO MI1O
# 3                                Balbuena
# 115                                 Antas

# %%
# Selección aleatoria del 25% de la tabla
prop_25 = econdata.sample(frac =.25)
prop_25.head()
# Out:
#       id                  geo_point_2d  \
# 26    26  19.4262321913,-99.1238893146
# 56    56  19.4452114301,-99.1425281852
# 76    76  19.4367072434,-99.1424407474
# 168  168   19.4349726565,-99.147766133
# 66    66  19.4331350004,-99.1382989213
#
#                                              geo_shape   clave_cat  \
# 26   {"type": "Polygon", "coordinates": [[[-99.1241...  323_064_01
# 56   {"type": "MultiPoint", "coordinates": [[-99.14...  003_043_01
# 76   {"type": "MultiPoint", "coordinates": [[-99.14...  003_095_02
# 168  {"type": "MultiPoint", "coordinates": [[-99.14...  002_014_23
# 66   {"type": "MultiPoint", "coordinates": [[-99.13...  001_021_14
#
#               delegacion perimetro     tipo                nom_id
# 26   Venustiano Carranza         B  Mercado  La Merced Nave Mayor
# 56             Cuautémoc         B    Hotel               Morelia
# 76             Cuautémoc         A    Museo           Franz Mayer
# 168            Cuautémoc         B    Hotel           One Alameda
# 66             Cuautémoc         A    Hotel               Coliseo

# %% [markdown]
# ### 2) Muestreo sistemático:

# %%
def systematic_sampling(econdata, step):

    indexes = np.arange(0, len(econdata), step=step)
    systematic_sample = econdata.iloc[indexes]
    return systematic_sample

systematic_sample = systematic_sampling(econdata, 3)

systematic_sample
# Out:
#       id                  geo_point_2d  \
# 0      0   19.424781053,-99.1327537959
# 3      3      19.42489472,-99.12073393
# 6      6      19.43553422,-99.12324801
# 9      9  19.4407152937,-99.1498060057
# 12    12      19.43990186,-99.14813347
# ..   ...                           ...
# 216  216  19.4247697438,-99.1249707246
# 219  219  19.4234096295,-99.1438351156
# 222  222   19.4397905042,-99.134628735
# 225  225      19.43094655,-99.12455418
# 228  228  19.4406567734,-99.1394531646
#
#                                              geo_shape   clave_cat  \
# 0    {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 3    {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 6    {"type": "MultiPoint", "coordinates": [[-99.12...  318_116_11
# 9    {"type": "MultiPoint", "coordinates": [[-99.14...  012_146_22
# 12   {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
# ..                                                 ...         ...
# 216  {"type": "Polygon", "coordinates": [[[-99.1250...  323_118_37
# 219  {"type": "MultiPoint", "coordinates": [[-99.14...  002_118_03
# 222  {"type": "MultiPoint", "coordinates": [[-99.13...  004_063_10
# 225  {"type": "MultiPoint", "coordinates": [[-99.12...  323_027_04
# 228  {"type": "MultiPoint", "coordinates": [[-99.13...  004_069_01
#
#               delegacion perimetro     tipo                  nom_id
# 0             Cuauhtémoc         B  Mercado             Pino Suárez
# 3    Venustiano Carranza         B    Hotel                Balbuena
# 6    Venustiano Carranza         B    Hotel    San Antonio Tomatlan
# 9              Cuautémoc         B    Hotel                 Detroit
# 12             Cuautémoc         B    Hotel                  La Paz
# ..                   ...       ...      ...                     ...
# 216  Venustiano Carranza         B  Mercado  Lamininas de La Merced
# 219            Cuautémoc         B    Hotel          Prado Floresta
# 222            Cuautémoc         A    Hotel                  Ladero
# 225  Venustiano Carranza         B    Hotel           Gran Veracruz
# 228            Cuautémoc         B    Museo        Tequila y Mescal
#
# [77 rows x 8 columns]

# %% [markdown]
# ### 3) Muestreo estratificado:

# %%
econdata['estratificado'] = econdata['delegacion'] + "," + econdata['tipo']
(econdata['estratificado'].value_counts() / len(econdata)).sort_values(ascending=False)
# Out:
# Cuautémoc,Hotel                0.643478
# Cuautémoc,Museo                0.156522
# Venustiano Carranza,Hotel      0.078261
# Cuauhtémoc,Mercado             0.073913
# Venustiano Carranza,Mercado    0.047826
# Name: estratificado, dtype: float64

# %% [markdown]
# Imagina que nuestros datos son diferentes y sabemos que la proporción es la siguiente:
#
# 1) Hoteles en Cuauhtémoc es de 0.5
#
# 2) Museos en Cuauhtémoc es de 0.2
#
# 3) Hoteles en Venuestiano Carranza es de 0.1
#
# 4) Mercados en Cuauhtémoc es de 0.1
#
# 5) Mercados en Venuestiano Carranza es de 0.1

# %% [markdown]
# def data_estratificada(econdata, nombres_columnas_estrat, valores_estrat, prop_estrat, random_state=None):
#
#     df_estrat = pd.DataFrame(columns = econdata.columns) # Creamos un data frame vacío con los nombres de las columnas de econdata
#
#     pos = -1
#     for i in range(len(valores_estrat)): # iteración sobre los valores estratificados
#         pos += 1
#         if pos == len(valores_estrat) - 1:
#             ratio_len = len(econdata) - len(df_estrat) # si es la iteración final calcula el número de valores de salida tenga el mismo número de filas que de entrada
#         else:
#             ratio_len = int(len(econdata) * prop_estrat[i]) # calcula el número de filas según la proporción deseada
#
#         df_filtrado = econdata[econdata[nombres_columnas_estrat] == valores_estrat[i]] # filtra los datos de origen según los valores seleccionados en la estratificación de datos
#         df_temp = df_filtrado.sample(replace=True, n=ratio_len, random_state=random_state) # haz un sample de los datos filtrados usando la ratio que hemos calculado
#
#         df_estrat = pd.concat([df_estrat, df_temp]) # junta las tablas de sample con la estratificada para producir el resultado final
#
#     return df_estrat # Return the stratified, re-sampled data

# %%
def data_estratificada(econdata, nombres_columnas_estrat, nombres_estratificar, prop_estrat, random_state=None):

    df_estratificado = pd.DataFrame(columns = econdata.columns) 
    
    pos = -1
    for i in range(len(nombres_estratificar)):
        pos += 1
        if pos == len(nombres_estratificar):
            ratio_len = len(econdata) - len(df_estratificado)
        else:
            ratio_len = int(len(econdata) * prop_estrat[i])

        #df_filtrado = econdata[econdata[nombres_columnas_estrat] == valores_estrat[i]]
        df_filter = econdata[nombres_columnas_estrat] == nombres_estratificar[i]
        df_filtered = econdata[df_filter]
        df_new = df_filtered.sample(replace=True, n=ratio_len, random_state=random_state)

        df_estratificado = pd.concat([df_estratificado, df_new])
    
    return df_estratificado

# %%
nombres_estratificar = ['Cuautémoc,Hotel', 'Cuautémoc,Museo', 'Venustiano Carranza,Hotel', 'Cuauhtémoc,Mercado','Venustiano Carranza,Mercado']
prop_estrat = [0.5, 0.2, 0.1, 0.1,0.1]
df_estrat = data_estratificada(econdata, 'estratificado', nombres_estratificar, prop_estrat, random_state=42)
df_estrat
# Out:
#       id                  geo_point_2d  \
# 164  164  19.4388741511,-99.1413308257
# 142  142  19.4263681354,-99.1327278126
# 27    27  19.4348360773,-99.1463945583
# 168  168   19.4349726565,-99.147766133
# 113  113      19.43374405,-99.13550135
# ..   ...                           ...
# 128  128  19.4270781084,-99.1210175514
# 37    37   19.4271233834,-99.125111772
# 163  163  19.4265454033,-99.1224859032
# 156  156  19.4255480371,-99.1249308096
# 37    37   19.4271233834,-99.125111772
#
#                                              geo_shape        clave_cat  \
# 164  {"type": "MultiPoint", "coordinates": [[-99.14...       003_113_03
# 142  {"type": "MultiPoint", "coordinates": [[-99.13...       006_127_14
# 27   {"type": "MultiPoint", "coordinates": [[-99.14...       002_016_01
# 168  {"type": "MultiPoint", "coordinates": [[-99.14...       002_014_23
# 113  {"type": "MultiPoint", "coordinates": [[-99.13...       001_012_13
# ..                                                 ...              ...
# 128  {"type": "Polygon", "coordinates": [[[-99.1214...  323_061_04(123)
# 37   {"type": "Polygon", "coordinates": [[[-99.1251...       323_065_01
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...       323_063_05
# 156  {"type": "Polygon", "coordinates": [[[-99.1253...   323_138_04 (3)
# 37   {"type": "Polygon", "coordinates": [[[-99.1251...       323_065_01
#
#               delegacion perimetro     tipo                   nom_id  \
# 164            Cuautémoc         B    Hotel             Dos Naciones
# 142            Cuautémoc         A    Hotel                    Ambar
# 27             Cuautémoc         B    Hotel  Hilton Centro Histórico
# 168            Cuautémoc         B    Hotel              One Alameda
# 113            Cuautémoc         A    Hotel              San Antonio
# ..                   ...       ...      ...                      ...
# 128  Venustiano Carranza         B  Mercado              San Ciprian
# 37   Venustiano Carranza         B  Mercado                 Dulceria
# 163  Venustiano Carranza         B  Mercado                      NaN
# 156  Venustiano Carranza         B  Mercado                 Mariscos
# 37   Venustiano Carranza         B  Mercado                 Dulceria
#
#                    estratificado
# 164              Cuautémoc,Hotel
# 142              Cuautémoc,Hotel
# 27               Cuautémoc,Hotel
# 168              Cuautémoc,Hotel
# 113              Cuautémoc,Hotel
# ..                           ...
# 128  Venustiano Carranza,Mercado
# 37   Venustiano Carranza,Mercado
# 163  Venustiano Carranza,Mercado
# 156  Venustiano Carranza,Mercado
# 37   Venustiano Carranza,Mercado
#
# [230 rows x 9 columns]
